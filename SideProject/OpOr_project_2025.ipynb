# %%
import numpy as np
import gurobipy as gp
from gurobipy import GRB


def solve_relaxation(X, u_lb, u_ub, v_lb, v_ub):
    m, n = X.shape
    model = gp.Model()
    

    # Variables
    u = model.addVars(m, lb=u_lb, ub=u_ub)
    v = model.addVars(n, lb=v_lb, ub=v_ub)
    z = model.addVars(m, n)
    t = model.addVars(m, n, lb=0)

    # Linearization constraints
    for i in range(m):
        for j in range(n):
            model.addConstr(u_ub[i] * v_ub[j] - v_ub[j] * u[i] - u_ub[i] * v[j] + z[i, j] >= 0)
            model.addConstr(-u_ub[i] * v_lb[j] + v_lb[j] * u[i] + u_ub[i] * v[j] - z[i, j] >= 0)
            model.addConstr(-u_lb[i] * v_ub[j] + v_ub[j] * u[i] + u_lb[i] * v[j] - z[i, j] >= 0)
            model.addConstr(u_lb[i] * v_lb[j] - v_lb[j] * u[i] - u_lb[i] * v[j] + z[i, j] >= 0)

    # Absolute error
    for i in range(m):
        for j in range(n):
            model.addConstr(t[i, j] >= X[i, j] - z[i, j])
            model.addConstr(t[i, j] >= z[i, j] - X[i, j])

    model.setObjective(gp.quicksum(t[i, j] for i in range(m) for j in range(n)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        u_val = np.array([u[i].X for i in range(m)])
        v_val = np.array([v[j].X for j in range(n)])
        return model.ObjVal, u_val, v_val
    else:
        return np.inf, None, None

# %%
def rank1l1NMF(X, delta):
    m, n = X.shape
    X_nnz = np.sum(X)

    u_lb, u_ub = np.zeros(m), np.ones(m)
    v_lb, v_ub = np.zeros(n), np.full(n, X_nnz + 1)

    best_u, best_v = None, None
    best_obj = np.inf
    best_bounds = None

    stack = [(u_lb.copy(), u_ub.copy(), v_lb.copy(), v_ub.copy())]

    while stack:
        ulb, uub, vlb, vub = stack.pop()

        # Bounding box too small?
        if max(uub - ulb) <= delta and max(vub - vlb) <= delta:
            obj, u_val, v_val = solve_relaxation(X, ulb, uub, vlb, vub)
            if obj < best_obj:
                best_obj = obj
                best_u, best_v = u_val, v_val
                best_bounds = (ulb.copy(), uub.copy(), vlb.copy(), vub.copy())
            continue

        # Solve LP relaxation
        obj, u_val, v_val = solve_relaxation(X, ulb, uub, vlb, vub)
        if obj >= best_obj:
            continue

        # Branching
        if max(uub - ulb) >= max(vub - vlb):
            i = np.argmax(uub - ulb)
            mid = (ulb[i] + uub[i]) / 2
            ulb1, uub1 = ulb.copy(), uub.copy()
            ulb2, uub2 = ulb.copy(), uub.copy()
            uub1[i], ulb2[i] = mid, mid
            stack.append((ulb1, uub1, vlb.copy(), vub.copy()))
            stack.append((ulb2, uub2, vlb.copy(), vub.copy()))
        else:
            j = np.argmax(vub - vlb)
            mid = (vlb[j] + vub[j]) / 2
            vlb1, vub1 = vlb.copy(), vub.copy()
            vlb2, vub2 = vlb.copy(), vub.copy()
            vub1[j], vlb2[j] = mid, mid
            stack.append((ulb.copy(), uub.copy(), vlb1, vub1))
            stack.append((ulb.copy(), uub.copy(), vlb2, vub2))

    if best_u is not None and best_bounds is not None:
        ulb_best, uub_best, vlb_best, vub_best = best_bounds
        return best_u, best_v, ulb_best, uub_best, vlb_best, vub_best
    else:
        return None, None, None, None, None, None

# %%
import numpy as np

X = np.array([
    [1, 1, 0],
    [1, 0, 0],
    [0, 1, 1]
])

delta = 0.1  # précision du branch & bound

u, v, u_min, u_max, v_min, v_max = rank1l1NMF(X, delta)

print("u =", np.round(u, 3))
print("v =", np.round(v, 3))
print("u @ v.T =\n", np.round(np.outer(u, v), 2))
print("||X - uvᵗ||₁ =", np.sum(np.abs(X - np.outer(u, v))))
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2661355
# Academic license - for non-commercial use only - expires 2026-05-06
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 108 nonzeros
# Model fingerprint: 0xec58846e
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 83 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.500000e+00   0.000000e+00      0s
#       11    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 114 nonzeros
# Model fingerprint: 0x7a44ecc1
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 87 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.0000000e+00   2.750000e+00   0.000000e+00      0s
#       11    5.0000000e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  5.000000000e-01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 120 nonzeros
# Model fingerprint: 0xc9000e3f
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 91 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.0000000e+00   3.000000e+00   0.000000e+00      0s
#       13    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x8b8c7e34
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2000000e+01   4.250000e+00   0.000000e+00      0s
#       15    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xd29d3c86
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.0500000e+01   4.750000e+00   0.000000e+00      0s
#       15    2.2500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.250000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xf73b82ce
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.07s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -9.0000000e+00   5.250000e+00   0.000000e+00      0s
#       15    2.2500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.09 seconds (0.00 work units)
# Optimal objective  2.250000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x8c4a3184
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -6.0000000e+00   6.625000e+00   0.000000e+00      0s
#       15    2.5000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.500000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xf128a216
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.2500000e+00   5.875000e+00   0.000000e+00      0s
#       15    2.6250000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  2.625000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x234d70ed
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -4.5000000e+00   5.125000e+00   0.000000e+00      0s
#       16    2.6250000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 16 iterations and 0.06 seconds (0.00 work units)
# Optimal objective  2.625000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xfaf6bbd6
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.0000000e+00   3.625000e+00   0.000000e+00      0s
#       20    2.7500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 20 iterations and 0.08 seconds (0.00 work units)
# Optimal objective  2.750000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x299ce4fc
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.03s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6250000e+00   2.625000e+00   0.000000e+00      0s
#       12    7.8750000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.06 seconds (0.00 work units)
# Optimal objective  7.875000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0xab9524f6
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 23 rows and 7 columns
# Presolve time: 0.03s
# Presolved: 31 rows, 17 columns, 75 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2000000e+01   1.000000e+00   0.000000e+00      0s
#        7    1.3750000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.375000000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 144 nonzeros
# Model fingerprint: 0x3446797c
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 27 rows and 9 columns
# Presolve time: 0.03s
# Presolved: 27 rows, 15 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8625000e+01   0.000000e+00   0.000000e+00      0s
#        0    1.8625000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.862500000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 144 nonzeros
# Model fingerprint: 0xc1210f18
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 27 rows and 9 columns
# Presolve time: 0.03s
# Presolved: 27 rows, 15 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9187500e+01   0.000000e+00   0.000000e+00      0s
#        0    1.9187500e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.918750000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 144 nonzeros
# Model fingerprint: 0x4d0358ee
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 27 rows and 9 columns
# Presolve time: 0.03s
# Presolved: 27 rows, 15 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9750000e+01   0.000000e+00   0.000000e+00      0s
#        0    1.9750000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.975000000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 144 nonzeros
# Model fingerprint: 0xb6e01c23
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 27 rows and 9 columns
# Presolve time: 0.03s
# Presolved: 27 rows, 15 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0312500e+01   0.000000e+00   0.000000e+00      0s
#        0    2.0312500e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.031250000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 144 nonzeros
# Model fingerprint: 0x317b2396
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 144 nonzeros
# Model fingerprint: 0x51b63c75
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.03s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 144 nonzeros
# Model fingerprint: 0x44168410
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x6415973f
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 23 rows and 7 columns
# Presolve time: 0.02s
# Presolved: 31 rows, 17 columns, 75 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2375000e+01   6.250000e-01   0.000000e+00      0s
#        4    1.3750000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.375000000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x498a287e
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 23 rows and 7 columns
# Presolve time: 0.02s
# Presolved: 31 rows, 17 columns, 75 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2937500e+01   4.375000e-01   0.000000e+00      0s
#        5    1.4196429e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.419642857e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x5d2d9851
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 23 rows and 7 columns
# Presolve time: 0.02s
# Presolved: 31 rows, 17 columns, 75 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3312500e+01   4.375000e-01   0.000000e+00      0s
#        6    1.4566667e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.456666667e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x4b360cf3
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 23 rows and 7 columns
# Presolve time: 0.03s
# Presolved: 31 rows, 17 columns, 75 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3687500e+01   4.375000e-01   0.000000e+00      0s
#        4    1.4875000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.487500000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0xca1dd1a9
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0xeab145aa
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0xdb1bc66f
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0xf39158fc
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.03s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.3750000e+00   1.875000e+00   0.000000e+00      0s
#       12    7.8750000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  7.875000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x0860bd91
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 25 rows and 8 columns
# Presolve time: 0.02s
# Presolved: 29 rows, 16 columns, 69 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1000000e+01   8.750000e-01   0.000000e+00      0s
#        4    1.2750000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.275000000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0xf069c0a5
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 25 rows and 8 columns
# Presolve time: 0.02s
# Presolved: 29 rows, 16 columns, 69 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1375000e+01   8.750000e-01   0.000000e+00      0s
#        4    1.3125000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.312500000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0xc90872a4
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 25 rows and 8 columns
# Presolve time: 0.02s
# Presolved: 29 rows, 16 columns, 69 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1937500e+01   6.875000e-01   0.000000e+00      0s
#        4    1.3500000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.350000000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x788b6416
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 25 rows and 8 columns
# Presolve time: 0.02s
# Presolved: 29 rows, 16 columns, 69 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2500000e+01   5.000000e-01   0.000000e+00      0s
#        4    1.3875000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.387500000e+01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x6805b8fe
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x829fe299
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 138 nonzeros
# Model fingerprint: 0x19939bb2
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0xef9e2176
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.03s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7500000e+00   1.500000e+00   0.000000e+00      0s
#       12    7.8750000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  7.875000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x441b4f84
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.02s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.1250000e+00   1.312500e+00   0.000000e+00      0s
#       12    8.1339286e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.08 seconds (0.00 work units)
# Optimal objective  8.133928571e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x39c664ae
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.02s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5000000e+00   1.125000e+00   0.000000e+00      0s
#       14    8.3166667e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  8.316666667e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x114f1f4a
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.02s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8750000e+00   9.375000e-01   0.000000e+00      0s
#       12    8.4375000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  8.437500000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x06836650
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x4579505c
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x1a416c0e
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xbb7db65c
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.6250000e+00   3.250000e+00   0.000000e+00      0s
#       21    2.7500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 21 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.750000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x3cf9f6db
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 19 rows and 5 columns
# Presolve time: 0.03s
# Presolved: 35 rows, 19 columns, 87 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.7500000e+00   1.625000e+00   0.000000e+00      0s
#       14    8.8750000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  8.875000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x638828df
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.8750000e+00   2.500000e+00   0.000000e+00      0s
#       20    2.7500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 20 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.750000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x4190f3da
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.02s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7500000e+00   1.500000e+00   0.000000e+00      0s
#       11    7.8750000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  7.875000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x28941f46
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.02s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9375000e+00   1.500000e+00   0.000000e+00      0s
#       11    8.0625000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  8.062500000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x5c793ac5
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.03s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.3125000e+00   1.312500e+00   0.000000e+00      0s
#        8    8.1833333e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  8.183333333e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x82085871
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.04s
# Presolved: 33 rows, 18 columns, 81 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8750000e+00   9.375000e-01   0.000000e+00      0s
#       11    8.4375000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.06 seconds (0.00 work units)
# Optimal objective  8.437500000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x0622f336
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0xc6f8f85d
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x59585fe1
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xbf8d1bde
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.5000000e+00   2.125000e+00   0.000000e+00      0s
#       22    2.7500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.750000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x7b749788
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.3125000e+00   1.937500e+00   0.000000e+00      0s
#       17    2.8125000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  2.812500000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x9f871634
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.1250000e+00   1.750000e+00   0.000000e+00      0s
#       17    2.8125000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  2.812500000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x545a448a
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.09s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.5000000e-01   1.375000e+00   0.000000e+00      0s
#       22    2.8750000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.11 seconds (0.00 work units)
# Optimal objective  2.875000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xa8db9119
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve time: 0.03s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x6bb9cc98
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x3acfd50d
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 6e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x7c571300
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.5000000e+00   3.125000e+00   0.000000e+00      0s
#       17    2.7916667e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.791666667e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0xa9a2e5ff
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+00]
#   Objective range  [1e+00, 1e+00]
# ...
#
# Optimize a model with 54 rows, 24 columns and 114 nonzeros
# Model fingerprint: 0xf6ce5d5f
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 87 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.0000000e-01   5.500000e+00   0.000000e+00      0s
#       14    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 120 nonzeros
# Model fingerprint: 0x93f2641b
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 18 rows and 4 columns
# Presolve time: 0.05s
# Presolved: 36 rows, 20 columns, 92 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.0000000e+00   5.375000e+00   0.000000e+00      0s
#       16    2.3333333e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 16 iterations and 0.08 seconds (0.00 work units)
# Optimal objective  2.333333333e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0x99c18950
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 18 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 36 rows, 20 columns, 94 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.0000000e-01   5.500000e+00   0.000000e+00      0s
#       19    3.2500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 19 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  3.250000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 120 nonzeros
# Model fingerprint: 0x6d63647e
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 20 rows and 5 columns
# Presolve time: 0.03s
# Presolved: 34 rows, 19 columns, 88 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5000000e-01   4.125000e+00   0.000000e+00      0s
#       13    2.3333333e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  2.333333333e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 126 nonzeros
# Model fingerprint: 0xbf7bb995
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 21 rows and 5 columns
# Presolve time: 0.03s
# Presolved: 33 rows, 19 columns, 93 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.6666667e-01   3.831833e+00   0.000000e+00      0s
#       14    2.6666667e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.06 seconds (0.00 work units)
# Optimal objective  2.666666667e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 132 nonzeros
# Model fingerprint: 0x4342b944
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [3e-01, 2e+00]
# Presolve removed 23 rows and 6 columns
# Presolve time: 0.02s
# Presolved: 31 rows, 18 columns, 87 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5000000e+00   2.748750e+00   0.000000e+00      0s
#       11    2.7500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.750000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 120 nonzeros
# Model fingerprint: 0x2d98287d
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 32 rows and 10 columns
# Presolve time: 0.02s
# Presolved: 22 rows, 14 columns, 66 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   3.998750e+00   0.000000e+00      0s
#        8    2.8333333e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  2.833333333e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 120 nonzeros
# Model fingerprint: 0x02007029
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 22 rows and 6 columns
# Presolve time: 0.06s
# Presolved: 32 rows, 18 columns, 84 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2500000e+00   3.125000e+00   0.000000e+00      0s
#       14    3.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.09 seconds (0.00 work units)
# Optimal objective  3.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 114 nonzeros
# Model fingerprint: 0xe0d6f6e8
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 19 rows and 5 columns
# Presolve time: 0.02s
# Presolved: 35 rows, 19 columns, 83 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.5000000e-03   5.503000e+00   0.000000e+00      0s
#       17    2.5000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.500000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 120 nonzeros
# Model fingerprint: 0xd1f9f252
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 19 rows and 5 columns
# Presolve time: 0.02s
# Presolved: 35 rows, 19 columns, 85 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.4850000e-01   5.503000e+00   0.000000e+00      0s
#       16    3.5000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 16 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.500000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 114 nonzeros
# Model fingerprint: 0x217150e2
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.05s
# Presolved: 33 rows, 18 columns, 79 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2485000e+00   4.253000e+00   0.000000e+00      0s
#       14    2.5000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.07 seconds (0.00 work units)
# Optimal objective  2.500000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 120 nonzeros
# Model fingerprint: 0x0c3cdc03
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 2e+00]
# Presolve removed 22 rows and 6 columns
# Presolve time: 0.04s
# Presolved: 32 rows, 18 columns, 84 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3333333e+00   3.331833e+00   0.000000e+00      0s
#       13    3.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.07 seconds (0.00 work units)
# Optimal objective  3.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 114 nonzeros
# Model fingerprint: 0x039a1817
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 2e+00]
#   RHS range        [5e-01, 1e+00]
# Presolve removed 23 rows and 7 columns
# Presolve time: 0.02s
# Presolved: 31 rows, 17 columns, 75 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7470000e+00   4.256000e+00   0.000000e+00      0s
#       11    3.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  3.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 108 nonzeros
# Model fingerprint: 0xb542915e
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 83 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.000000e+00   0.000000e+00      0s
#       16    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 16 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 114 nonzeros
# Model fingerprint: 0xe4baad6f
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.03s
# Presolved: 37 rows, 20 columns, 85 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.0000000e+00   8.000000e+00   0.000000e+00      0s
#       17    3.1666667e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  3.166666667e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 108 nonzeros
# Model fingerprint: 0x1e77e7c2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 20 columns, 83 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.000000e+00   0.000000e+00      0s
#       17    2.5000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.07 seconds (0.00 work units)
# Optimal objective  2.500000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 114 nonzeros
# Model fingerprint: 0xef30b3c0
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 1e+00]
#   RHS range        [5e-01, 1e+00]
# Presolve removed 17 rows and 4 columns
# Presolve time: 0.04s
# Presolved: 37 rows, 20 columns, 87 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.0000000e-01   5.500000e+00   0.000000e+00      0s
#       17    2.7500000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  2.750000000e+00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i5-1035G4 CPU @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 54 rows, 24 columns and 108 nonzeros
# Model fingerprint: 0xba1b8e40
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-01, 1e+00]
#   RHS range        [5e-01, 1e+00]
# Presolve removed 21 rows and 6 columns
# Presolve time: 0.02s
# Presolved: 33 rows, 18 columns, 75 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9700000e-01   5.006000e+00   0.000000e+00      0s
#       14    3.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  3.000000000e+00
# u = [0.222 0.    0.2  ]
# v = [3.8 4.7 0.7]
# u @ v.T =
#  [[0.84 1.04 0.16]
#  [0.   0.   0.  ]
#  [0.76 0.94 0.14]]
# ||X - uvᵗ||₁ = 3.0355555555555553
